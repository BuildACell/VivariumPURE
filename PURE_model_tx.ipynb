# %% [markdown]
# # Create a SBML Model With BioCRNpyler

# %%
from biocrnpyler import *
from vivarium.core.engine import pp

# %% [markdown]
# # More Complex Tx Model

# %%
G = Species("G")
T = Species("T")
RNAP = Species("RNAP")
C1 = Complex([G, RNAP])
NTP = Species("NTP")
Pi = Species("Phosphate")


kb = ParameterEntry(parameter_name = "kb", parameter_value = 1.0)
ku = ParameterEntry(parameter_name = "ku", parameter_value = 1.0)
r1 = Reaction.from_massaction(inputs = [G, RNAP], outputs = [C1], k_forward = kb, k_reverse = ku)

ktx = ParameterEntry(parameter_name = "ktx", parameter_value = .01)
N_G = ParameterEntry(parameter_name = f"N{G}", parameter_value = 350.0)
prop2 = GeneralPropensity(propensity_function = f"ktx*NG*{C1}*{NTP}", 
                          propensity_species = [C1, NTP], 
                          propensity_parameters = [ktx, N_G])
r2 = Reaction(inputs = [C1, NTP], outputs = [C1, Pi], propensity_type = prop2)

prop3 = ProportionalHillPositive(s1 = NTP, d = C1, K = 500, n = 2, k = ktx)
r3 = Reaction(inputs = [C1], outputs = [G, T, RNAP], propensity_type = prop3)

initial_concentration_dict = {
    G : 0.01,
    T : 0.0,
    RNAP : 1.5, #10x dilution of E. Coli
    C1 : 0,
    NTP : 5000
}

CRN_tx = ChemicalReactionNetwork(
    species = [G, T, RNAP, C1, NTP, Pi],
    reactions = [r1, r2, r3],
    initial_concentration_dict = initial_concentration_dict)

print(CRN_tx.pretty_print())

CRN_tx.write_sbml_file("tx.xml")
# Out:
# Species(N = 6) = {
# NTP (@ 5000),  RNAP (@ 1.5),  G (@ 0.01),  T (@ 0.0),  Phosphate (@ 0),  complex[G:RNAP] (@ 0),
# }
#
# Reactions (3) = [
# 0. G+RNAP <--> complex[G:RNAP]
#  Kf=k_forward * G * RNAP
#  Kr=k_reverse * complex_G_RNAP_
#   k_forward=1.0
#   k_reverse=1.0
#
# 1. complex[G:RNAP]+NTP --> complex[G:RNAP]+Phosphate
# ktx*NG*complex_G_RNAP_*NTP
#   ktx=0.01
#   NG=350.0
#
# 2. complex[G:RNAP] --> G+T+RNAP
#  Kf = k complex[G:RNAP] NTP^n / ( K^n + NTP^n )
#   k=0.01
#   K=500
#   n=2
#
# ]
# True

# %%
# %matplotlib inline
from vivarium.core import store
from vivarium_bioscrape.processes.bioscrape import Bioscrape

tx_parameters = {
    "sbml_file":"tx.xml",
    "timestep": 1.0
}

#Create a Store
S = store.Store({})
bioscrape_process = Bioscrape(tx_parameters)
S["tx"] = bioscrape_process
S.set_value(bioscrape_process.initial_state())
print(pp(S.get_value()))
# Out:
# { 'delta_species': { 'G': 0.0,
#                      'NTP': 0.0,
#                      'Phosphate': 0.0,
#                      'RNAP': 0.0,
#                      'T': 0.0,
#                      'complex_G_RNAP_': 0.0},
#   'globals': {'volume': 1.0},
#   'rates': { 'K': 500.0,
#              'NG': 350.0,
#              'kb__': 1.0,
#              'ktx': 0.01,
#              'ktx__': 0.01,
#              'ku__': 1.0,
#              'n': 2.0},
#   'species': { 'G': 0.01,
#                'NTP': 5000.0,
#                'Phosphate': 0.0,
#                'RNAP': 1.5,
#                'T': 0.0,
#                'complex_G_RNAP_': 0.0},
#   'tx': ( <vivarium_bioscrape.processes.bioscrape.Bioscrape object at 0x000002AA0A221748>,
#           { 'delta_species': ('delta_species',),
#             'globals': ('globals',),
#             'rates': ('rates',),
#             'species': ('species',)})}
# None

# %%
from vivarium.core.engine import Engine

# put the store in an engine and run it
sim = Engine(store=S)
steps = 300
sim.update(steps)
# Out:
# Simulation ID: 45c9e65c-9e72-11ec-96ac-6c2b5976b3a5
# Created: 03/07/2022 at 15:56:57
# Completed in 0.078807 seconds

# %%
# %matplotlib inline
from vivarium.plots.simulation_output import plot_variables

# get the data
data = sim.emitter.get_timeseries()
#Plot the data
fig = plot_variables(data, variables=[
    ('species', 'G'),
    ('species', 'T'),
    ('species', 'RNAP'),
    ('species', str(NTP)),
    ('species', str(Pi))])

# %% [markdown]
# # TL Model

# %%
#T = Species("T")
#NTP = SpecieS("NTP")
#Pi = Species("phosphate")
tRNA = Species("tRNA")
aa = Species("amino_acid")
prot = Species("Protein")
ribo = Species("Ribosome")
C2 = Complex([T, ribo])
C3 = Complex([tRNA, NTP, aa])

r4 = Reaction.from_massaction(inputs = [T, ribo], outputs = [C2], k_forward = kb, k_reverse = ku)
r5 = Reaction.from_massaction(inputs = [tRNA, NTP, aa], outputs = [C3], k_forward = kb, k_reverse = ku)


ktl = ParameterEntry(parameter_name = "ktl", parameter_value = .05) #uM protein produced / min
N_P = ParameterEntry(parameter_name = f"N{prot}", parameter_value = 117) #protein length
prop6 = GeneralPropensity(propensity_function = f"ktl*NProtein*{C2}*{C3}", 
                          propensity_species = [C2, C3], 
                          propensity_parameters = [ktl, N_P])

r6 = Reaction(inputs = [C2, C3], outputs = [C2, tRNA, Pi], propensity_type = prop6)

prop7 = ProportionalHillPositive(s1 = C3, d = C2, K = 500, n = 2, k = ktl)
r7 = Reaction(inputs = [C2], outputs = [T, ribo, prot], propensity_type = prop7)

initial_concentration_dict = {
    T : 0.0,
    ribo : 15, #10x dilution of E. Coli
    NTP : 5000,
    aa : 20000,
    tRNA : 75
}

CRN_tl = ChemicalReactionNetwork(
    species = [T, ribo, C2, C3, NTP, Pi, aa, prot, tRNA],
    reactions = [r4, r5, r6, r7],
    initial_concentration_dict = initial_concentration_dict)

print(CRN_tl.pretty_print())

CRN_tl.write_sbml_file("tl.xml")
# Out:
# Species(N = 9) = {
# amino_acid (@ 20000),  NTP (@ 5000),  tRNA (@ 75),  Ribosome (@ 15),  T (@ 0.0),  complex[Ribosome:T] (@ 0),  Protein (@ 0),  Phosphate (@ 0),  complex[NTP:amino_acid:tRNA] (@ 0),
# }
#
# Reactions (4) = [
# 0. T+Ribosome <--> complex[Ribosome:T]
#  Kf=k_forward * T * Ribosome
#  Kr=k_reverse * complex_Ribosome_T_
#   k_forward=1.0
#   k_reverse=1.0
#
# 1. tRNA+NTP+amino_acid <--> complex[NTP:amino_acid:tRNA]
#  Kf=k_forward * tRNA * NTP * amino_acid
#  Kr=k_reverse * complex_NTP_amino_acid_tRNA_
#   k_forward=1.0
#   k_reverse=1.0
#
# 2. complex[Ribosome:T]+complex[NTP:amino_acid:tRNA] --> complex[Ribosome:T]+tRNA+Phosphate
# ktl*NProtein*complex_Ribosome_T_*complex_NTP_amino_acid_tRNA_
#   ktl=0.05
#   NProtein=117
#
# 3. complex[Ribosome:T] --> T+Ribosome+Protein
#  Kf = k complex[Ribosome:T] complex[NTP:amino_acid:tRNA]^n / ( K^n + complex[NTP:amino_acid:tRNA]^n )
#   k=0.05
#   K=500
#   n=2
#
# ]
# True

# %%
from vivarium.core.engine import Engine
from vivarium.core.composer import Composite


tl_parameters = {
    "sbml_file":"tl.xml",
    "timestep": 1.0
}

#Create a Store
S = store.Store({})
bioscrape_process = Bioscrape(tl_parameters)
S["tl"] = bioscrape_process
S.set_value(bioscrape_process.initial_state())
print(pp(S.get_value()))


# put the store in an engine and run it
sim = Engine(store=S)
steps = 300
sim.update(steps)
# Out:
# { 'delta_species': { 'NTP': 0.0,
#                      'Phosphate': 0.0,
#                      'Protein': 0.0,
#                      'Ribosome': 0.0,
#                      'T': 0.0,
#                      'amino_acid': 0.0,
#                      'complex_NTP_amino_acid_tRNA_': 0.0,
#                      'complex_Ribosome_T_': 0.0,
#                      'tRNA': 0.0},
#   'globals': {'volume': 1.0},
#   'rates': { 'K': 500.0,
#              'NProtein': 117.0,
#              'kb__': 1.0,
#              'ktl': 0.05,
#              'ktl__': 0.05,
#              'ku__': 1.0,
#              'n': 2.0},
#   'species': { 'NTP': 5000.0,
#                'Phosphate': 0.0,
#                'Protein': 0.0,
#                'Ribosome': 15.0,
#                'T': 0.0,
#                'amino_acid': 20000.0,
#                'complex_NTP_amino_acid_tRNA_': 0.0,
#                'complex_Ribosome_T_': 0.0,
#                'tRNA': 75.0},
#   'tl': ( <vivarium_bioscrape.processes.bioscrape.Bioscrape object at 0x000002AA063CE188>,
#           { 'delta_species': ('delta_species',),
#             'globals': ('globals',),
#             'rates': ('rates',),
#             'species': ('species',)})}
# None
#
# Simulation ID: 460c95f6-9e72-11ec-a627-6c2b5976b3a5
# Created: 03/07/2022 at 15:56:58
# Completed in 0.088523 seconds

# %%
# %matplotlib inline
from vivarium.plots.simulation_output import plot_variables

# get the data
data = sim.emitter.get_timeseries()
#Plot the data
fig = plot_variables(data, variables=[
    ('species', 'T'),
    ('species', str(prot)),
    ('species', str(aa)),
    ('species', str(NTP)),
    ('species', str(Pi)),
    ('species', str(ribo)),
    ('species', str(tRNA))])

# %%
S = store.Store({})
S['tx'] = Bioscrape(tx_parameters)
S.set_value(S['tx'].value.initial_state())
S['tl'] = Bioscrape(tl_parameters)
S.set_value(S['tl'].value.initial_state())


#Plot Topology
composite = Composite(store=S)
fig = plot_topology(composite)

# put the store in an engine and run it
sim = Engine(store=S)
steps = 300
sim.update(steps)

print(pp(S.get_value()))
# Out:
# Simulation ID: 4955a040-9e72-11ec-aec7-6c2b5976b3a5
# Created: 03/07/2022 at 15:57:03
# Completed in 0.202769 seconds
# { 'delta_species': { 'G': 0.0,
#                      'NTP': -1.5327864566645507e-08,
#                      'Phosphate': 0.05856035988472286,
#                      'Protein': 3.596707918150123e-09,
#                      'RNAP': 0.0,
#                      'Ribosome': -1.4873435816298297e-11,
#                      'T': -1.4870239859344353e-11,
#                      'amino_acid': -1.531225279904902e-08,
#                      'complex_G_RNAP_': 0.0,
#                      'complex_NTP_amino_acid_tRNA_': -0.05856034456507753,
#                      'complex_Ribosome_T_': 1.4870237853570334e-11,
#                      'tRNA': 0.05856034456500936},
#   'globals': {'volume': 1.0},
#   'rates': { 'K': 500.0,
#              'NG': 350.0,
#              'NProtein': 117.0,
#              'kb__': 1.0,
#              'ktl': 0.05,
#              'ktl__': 0.05,
#              'ktx': 0.01,
#              'ktx__': 0.01,
#              'ku__': 1.0,
#              'n': 2.0},
#   'species': { 'G': 0.004009607649196526,
#                'NTP': 1.2048021825188375e-06,
#                'Phosphate': 4998.232755420312,
#                'Protein': 0.0008770664753434863,
#                'RNAP': 1.4940096076492455,
#                'Ribosome': 14.994371168807636,
#                'T': 0.00037539651778121174,
#                'amino_acid': 19613.144660876893,
#                'complex_G_RNAP_': 0.005990392350803474,
#                'complex_NTP_amino_acid_tRNA_': 1.7672433746705256,
#                'complex_Ribosome_T_': 0.005628831192661326,
#                'tRNA': 73.23275662533077},
#   'tl': ( <vivarium_bioscrape.processes.bioscrape.Bioscrape object at 0x000002AA079A5588>,
#           { 'delta_species': ('delta_species',),
#             'globals': ('globals',),
#             'rates': ('rates',),
#             'species': ('species',)}),
#   'tx': ( <vivarium_bioscrape.processes.bioscrape.Bioscrape object at 0x000002AA079A5D88>,
#           { 'delta_species': ('delta_species',),
#             'globals': ('globals',),
#             'rates': ('rates',),
#             'species': ('species',)})}
# None

# %%
# %matplotlib inline
from vivarium.plots.simulation_output import plot_variables

# get the data
data = sim.emitter.get_timeseries()
#Plot the data
fig = plot_variables(data, variables=[
    ('species', str(G)),
    ('species', str(prot)),
    ('species', str(aa)),
    ('species', str(NTP)),
    ('species', str(Pi)),
    ('species', str(ribo)),
    ('species', str(tRNA))])

# %% [markdown]
# # TX/TL module

# %% [markdown]
# ## Use [BioCRNpyler](https://github.com/BuildACell/BioCRNPyler) to make a Chemical Reaction Network (CRN)
#
# An unrealistically simple model of transcription from a gene $G$ to a transcript $T$ to a protein $P$
#
# ## $G \to G + T$
# ## $T \to T + P$

# %%
G = Species("G")
T = Species("T")
P = Species("P")

ktx = 1.0
ktl = 1.0
txrxn = Reaction.from_massaction(inputs = [G], outputs = [G, T], k_forward=ktx)
tlrxn = Reaction.from_massaction(inputs = [T], outputs = [T, P], k_forward=ktl)

CRN = ChemicalReactionNetwork(
    species = [G, T, P], 
    reactions = [txrxn, tlrxn],
    initial_concentration_dict = {G:1, T:0, P:0})

print(CRN.pretty_print(show_compartment = True))

CRN.write_sbml_file("txtl.xml")
# Out:
# Species(N = 3) = {
# G (@ 1),  T (@ 0),  P (@ 0),
# }
#
# Reactions (2) = [
# 0. G --> G+T
#  Kf=k_forward * G
#   k_forward=1.0
#
# 1. T --> T+P
#  Kf=k_forward * T
#   k_forward=1.0
#
# ]
# True

# %% [markdown]
# ## Load the CRN into [Vivarium-Bioscrape](https://github.com/vivarium-collective/vivarium-bioscrape)
#
# [Vivarium](https://academic.oup.com/bioinformatics/advance-article-abstract/doi/10.1093/bioinformatics/btac049/6522109?redirectedFrom=fulltext) is a multiscale-multimodal simulation engine with [many supported simulators](https://github.com/orgs/vivarium-collective/repositories?type=all). [Bioscrape](https://github.com/biocircuits/bioscrape) is a CRN simulator which can load the SBML files produced by BioCRNpyler. Vivarium-Bioscrape is Vivarium wrapper around Bioscrape.

# %%
from vivarium.core import store
from vivarium_bioscrape.processes.bioscrape import Bioscrape

txtl_parameters = {
    "sbml_file":"txtl.xml",
    "timestep": 1.0
}

#Create a Store
S = store.Store({})
bioscrape_process = Bioscrape(txtl_parameters)
S["txtl"] = bioscrape_process
S.set_value(bioscrape_process.initial_state())
print(pp(S.get_value()))
# Out:
# { 'delta_species': {'G': 0.0, 'P': 0.0, 'T': 0.0},
#   'globals': {'volume': 1.0},
#   'rates': {'k_forward': 1.0, 'k_forward_r1': 1.0},
#   'species': {'G': 1.0, 'P': 0.0, 'T': 0.0},
#   'txtl': ( <vivarium_bioscrape.processes.bioscrape.Bioscrape object at 0x000001B8FDEA8CC8>,
#             { 'delta_species': ('delta_species',),
#               'globals': ('globals',),
#               'rates': ('rates',),
#               'species': ('species',)})}
# None

# %% [markdown]
# ## Plot the topology

# %%
from vivarium.core.composer import Composite
from vivarium.plots.topology import plot_topology

composite = Composite(store=S)
fig = plot_topology(composite)

# %% [markdown]
# ## Run the Vivarium-Bioscrape TXTL process alone then plot the results

# %%
# %matplotlib inline
from vivarium.core.engine import Engine

# put the store in an engine and run it
sim = Engine(store=S)
steps = 100
sim.update(steps)
# Out:
# Simulation ID: ad7ac8ae-9e47-11ec-9453-6c2b5976b3a5
# Created: 03/07/2022 at 10:52:03
# Completed in 0.021941 seconds

# %%
from vivarium.plots.simulation_output import plot_variables

# get the data
data = sim.emitter.get_timeseries()
#Plot the data
fig = plot_variables(data, variables=[
    ('species', 'G'),
    ('species', 'T'),
    ('species', 'P')])

# %% [markdown]
# # A Second Transcription Process
#
# ### $RNAP + G \rightleftharpoons RNAP:G \to RNAP + G + T$

# %%
#Create a CRN
G = Species("G")
RNAP = Species("RNAP")
G_RNAP = Complex([G, RNAP])
T = Species("T")

ktx = ParameterEntry(parameter_name = "ktx", parameter_value = 1.0)
kb = ParameterEntry(parameter_name = "kb", parameter_value = 100.0)
ku = ParameterEntry(parameter_name = "ku", parameter_value = 1.0)

r1 = Reaction.from_massaction(inputs=[G, RNAP], outputs = [G_RNAP], k_forward = kb, k_reverse = ku)
r2 = Reaction.from_massaction(inputs = [G_RNAP], outputs = [G, RNAP, T], k_forward = ktx)

CRN2 = ChemicalReactionNetwork(
    species = [G, RNAP, G_RNAP, T], 
    reactions = [r1, r2],
    initial_concentration_dict = {G:1, T:0, RNAP:10})

print(CRN2.pretty_print(show_compartment = True))

#Save the CRN
CRN2.write_sbml_file("tx.xml")

#Load into Vivarium-Bioscrape
tx_parameters = {
    "sbml_file":"tx.xml",
    "timestep": 1.0
}

#Create a Store
S = store.Store({})
bioscrape_process = Bioscrape(tx_parameters)
S["tx"] = bioscrape_process
S.set_value(bioscrape_process.initial_state())
print(pp(S.get_value()))

#Plot Topology
composite = Composite(store=S)
fig = plot_topology(composite)

#Simulate
sim = Engine(store=S)
steps = 100
sim.update(steps)

# get the data
data = sim.emitter.get_timeseries()
#Plot the data
fig = plot_variables(data, variables=[
    ('species', 'G'),
    ('species', 'T'),
    ('species', 'RNAP')])
# Out:
# Species(N = 4) = {
# RNAP (@ 10),  G (@ 1),  T (@ 0),  complex[G:RNAP] (@ 0),
# }
#
# Reactions (2) = [
# 0. G+RNAP <--> complex[G:RNAP]
#  Kf=k_forward * G * RNAP
#  Kr=k_reverse * complex_G_RNAP_
#   k_forward=100.0
#   k_reverse=1.0
#
# 1. complex[G:RNAP] --> G+RNAP+T
#  Kf=k_forward * complex_G_RNAP_
#   k_forward=1.0
#
# ]
# { 'delta_species': {'G': 0.0, 'RNAP': 0.0, 'T': 0.0, 'complex_G_RNAP_': 0.0},
#   'globals': {'volume': 1.0},
#   'rates': {'kb__': 100.0, 'ktx__': 1.0, 'ku__': 1.0},
#   'species': {'G': 1.0, 'RNAP': 10.0, 'T': 0.0, 'complex_G_RNAP_': 0.0},
#   'tx': ( <vivarium_bioscrape.processes.bioscrape.Bioscrape object at 0x000001B88706BE08>,
#           { 'delta_species': ('delta_species',),
#             'globals': ('globals',),
#             'rates': ('rates',),
#             'species': ('species',)})}
# None
#
# Simulation ID: bb587070-9e49-11ec-add9-6c2b5976b3a5
# Created: 03/07/2022 at 11:06:45
# Completed in 0.021941 seconds

# %% [markdown]
# # Create a Custom Vivarium Process to Model Transcription Rate Dependence on the Amounts of Various Chemicals Using Hill Functions

# %%
from vivarium.core.process import Process
import numpy as np


class TxRate(Process):

    defaults = {
        'K': 5,
        'n': 2,
    }

    def __init__(self, parameters=None):
        super().__init__(parameters)

    def ports_schema(self):
        return {
            'rates': {
                '*': {
                    '_default': 0.0,
                    '_emit': True,
                    '_updater': 'set'
                }
            },
            'species': {
                "*": {
                '_default': 0.0,
                '_emit': True,
                }
            }
        }

    def next_update(self, timestep, states):
        ktx = states['rates']['ktx__']
        T = states['species']['T']
        K = self.parameters["K"]
        n = self.parameters["n"]
        
        
        new_ktx = ktx/(1 + (T/K)**n)
        
        
        return { 
            'rates':{
                "ktx__":new_ktx
            }
        }

# %%
#Create a Store
S = store.Store({})

# make bioscrape
txtl_parameters = {
    "sbml_file":"tx.xml",
    "timestep": 1.0
}
tx_process = Bioscrape(tx_parameters)
S["tx_process"] = tx_process
tx_initial = tx_process.initial_state()
S.set_value(tx_initial)

# get the rates for bioscrape_process
rates = {'ktx': 1.0}
txrate_process = TxRate({
    'K': 10.,
    'n': 2.,
    'rates':rates
})
S["txrate_process"] = txrate_process


print(pp(S.get_value()))

composite = Composite(store=S)
fig = plot_topology(composite)

# put the store in an engine and run it
sim = Engine(store=S)
steps = 100
sim.update(steps)

data = sim.emitter.get_timeseries()
fig = plot_variables(data, variables=[
    ('species', 'G'),
    ('species', 'T'),
    ('species', 'RNAP'),
    ('species', str(G_RNAP)),
    ('rates', 'ktx__')
#     ('salt',),
])
# Out:
# { 'delta_species': {'G': 0.0, 'RNAP': 0.0, 'T': 0.0, 'complex_G_RNAP_': 0.0},
#   'globals': {'volume': 1.0},
#   'rates': {'kb__': 100.0, 'ktx__': 1.0, 'ku__': 1.0},
#   'species': {'G': 1.0, 'RNAP': 10.0, 'T': 0.0, 'complex_G_RNAP_': 0.0},
#   'tx_process': ( <vivarium_bioscrape.processes.bioscrape.Bioscrape object at 0x000001B887273348>,
#                   { 'delta_species': ('delta_species',),
#                     'globals': ('globals',),
#                     'rates': ('rates',),
#                     'species': ('species',)}),
#   'txrate_process': ( <__main__.TxRate object at 0x000001B887284448>,
#                       {'rates': ('rates',), 'species': ('species',)})}
# None
#
# Simulation ID: c03afb40-9e4b-11ec-9200-6c2b5976b3a5
# Created: 03/07/2022 at 11:21:12
# Completed in 0.030602 seconds

# %% [markdown]
# # Adding more complexity via a custom Vivarium `Process`
#
# In the following example, we model how salt concentration may effect chemical reaction rates. This model is a heuristic we invented as an example. It assmumes that salt concentrations causes a super-exponential drop in expression (modeled by a Guassian) as it deviates from the optimal value.
#
# ### All Vivarium `Processes`Require:
# * a `ports_schema` which defines the variables names passed into `Process.next_update`as a `state` dictionary
# * a set of `default` used for internal parameter values (these can be updated via the `parameters` in the constructor
# * a `next_update` function which takes a state and updates it

# %%
from vivarium.core.process import Process
import numpy as np

def gaussian(x, mean, variance):
    return np.exp(-(x - mean) ** 2 / variance)

class Salt(Process):

    defaults = {
        'mean': 5, # (Mg) this is the salt concentration for max activity
        'variance': 2,
        'max_rates': {},
    }

    def __init__(self, parameters=None):
        super().__init__(parameters)

    def ports_schema(self):
        return {
            'rates': {
                '*': {
                    '_default': 0.0,
                    '_emit': True,
                    '_updater': 'set'
                }
            },
            'salt': {
                '_default': 0.0,
                '_emit': True,
            }
        }

    def next_update(self, timestep, states):
        salt = states['salt']
        
        activity = gaussian(
            salt, self.parameters['mean'], self.parameters['variance'])
        
        return {
            'rates': {
                param_id: max_rate*activity 
                for param_id, max_rate in self.parameters['rates'].items()}
        }

# %%
import pylab as plt

plt.plot(np.arange(0,10,0.1), [gaussian(x, mean=5, variance=10) for x in np.arange(0,10,0.1)])

# %% [markdown]
# # Wiring `Processes` Together with `Stores`
#
# `Stores` are the Vivarium objects which hold the state variables that are accesssed by different processes. By sharing variables in a `Store`, different `Processes` can be coupled together during simulation. To do this, each `Process` is places inside a `Store`. Because the port_schema of the Bioscrape and Salt Processes both contain variables called `rates`, these will automatically be shared between the processes.

# %%
#Create a Store
S2 = store.Store({})

# make bioscrape
txtl_parameters = {
    "sbml_file":"txtl.xml",
    "timestep": 1.0
}
txtl_process = Bioscrape(txtl_parameters)
S2["txtl_process"] = bioscrape_process
txtl_initial = txtl_process.initial_state()
S2.set_value(txtl_initial)

# get the rates for bioscrape_process
rates = {'k_forward': 1.0, 'k_forward_r1': 1.0}
salt_process = Salt({
    'mean': 5.,
    'variance': 1.,
    'rates': rates,
})
S2["salt_process"] = salt_process
S2["salt"] = 4.

print(pp(S2.get_value()))
# Out:
# { 'delta_species': {'G': 0.0, 'P': 0.0, 'T': 0.0},
#   'globals': {'volume': 1.0},
#   'rates': {'k_forward': 1.0, 'k_forward_r1': 1.0},
#   'salt': 4.0,
#   'salt_process': ( <__main__.Salt object at 0x12ee817c0>,
#                     {'rates': ('rates',), 'salt': ('salt',)}),
#   'species': {'G': 1.0, 'P': 0.0, 'T': 0.0},
#   'txtl_process': ( <vivarium_bioscrape.processes.bioscrape.Bioscrape object at 0x11f59ddc0>,
#                     { 'delta_species': ('delta_species',),
#                       'globals': ('globals',),
#                       'rates': ('rates',),
#                       'species': ('species',)})}
# None

# %% [markdown]
# ## Plot the topology

# %%
from vivarium.core.composer import Composite
from vivarium.plots.topology import plot_topology

composite = Composite(store=S2)
fig = plot_topology(composite)

# %% [markdown]
# # Simulate the 2-Process Model

# %%
# %matplotlib inline
from vivarium.core.engine import Engine

# put the store in an engine and run it
sim2 = Engine(store=S2)
steps = 100
sim2.update(steps)
# Out:
# Simulation ID: ebfec414-9ca2-11ec-bc97-8c85908ac627
# Created: 03/05/2022 at 08:40:09
# Completed in 0.030456 seconds

# %% [markdown]
# ## Vary the salt concentration

# %%
# put the store in an engine and run it
S2.set_value(txtl_initial)
S2["salt"] = 4.
sim2 = Engine(store=S2)
steps = 100
sim2.update(steps)

# get the data
data = sim2.emitter.get_timeseries()
fig = plot_variables(data, variables=[
    ('species', 'G'),
    ('species', 'T'),
    ('species', 'P'),
#     ('salt',),
])
# Out:
# Simulation ID: ec04893a-9ca2-11ec-bc97-8c85908ac627
# Created: 03/05/2022 at 08:40:09
# Completed in 0.031908 seconds

# %%
# put the store in an engine and run it
S2.set_value(txtl_initial)
S2["salt"] = 2
sim2 = Engine(store=S2)
steps = 100
sim2.update(steps)

# get the data
data = sim2.emitter.get_timeseries()
fig = plot_variables(data, variables=[
    ('species', 'G'),
    ('species', 'T'),
    ('species', 'P'),
#     ('salt',),
])
# Out:
# Simulation ID: ec3343c4-9ca2-11ec-bc97-8c85908ac627
# Created: 03/05/2022 at 08:40:10
# Completed in 0.026990 seconds
